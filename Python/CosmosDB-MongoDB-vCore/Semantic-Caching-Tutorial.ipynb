# %% [markdown]
# # Introduction
#
# In this tutorial, we'll demonstrate how to leverage a semantic caching with Azure Cosmos DB for MongoDB and LangChain.
#
# [Learn more here from the LangChain docs.](https://python.langchain.com/docs/integrations/llms/llm_caching#azure-cosmos-db-semantic-cache)

# %%
! pip install langchain
! pip install langchain_openai
! pip install langchain_community
! pip install pymongo
! pip install python-dotenv
! pip install azure-core
! pip install azure-cosmos
# Out:
# Collecting langchain
#   Downloading langchain-0.2.0-py3-none-any.whl.metadata (13 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.30-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_core-0.2.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.59-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.3-cp312-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ---------------------------------------- 50.9/50.9 kB ? eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-0.2.0-py3-none-any.whl (973 kB)
#    ---------------------------------------- 0.0/973.7 kB ? eta -:--:--
#    ------------------- ------------------- 481.3/973.7 kB 15.2 MB/s eta 0:00:01
#    --------------------------------------- 973.7/973.7 kB 20.5 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl (369 kB)
#    ---------------------------------------- 0.0/369.0 kB ? eta -:--:--
#    ---------------------------------------- 369.0/369.0 kB ? eta 0:00:00
# Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Downloading langchain_core-0.2.0-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.9 kB ? eta -:--:--
#    ---------- ----------------------------- 81.9/307.9 kB ? eta -:--:--
#    ---------- ----------------------------- 81.9/307.9 kB ? eta -:--:--
#    ------------ ------------------------- 102.4/307.9 kB 845.5 kB/s eta 0:00:01
#    --------------------------- ------------ 215.0/307.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 307.9/307.9 kB 1.6 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.0-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.59-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.2 kB ? eta -:--:--
#    ---------------------------------------- 121.2/121.2 kB ? eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    ---------------------------------------- 138.7/138.7 kB ? eta 0:00:00
# Downloading SQLAlchemy-2.0.30-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------------------------- ------- 1.7/2.1 MB 53.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 44.9 MB/s eta 0:00:00
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB ? eta 0:00:00
# Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.6 kB ? eta -:--:--
#    --------------------------------------- 293.6/293.6 kB 17.7 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB ? eta 0:00:00
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading orjson-3.10.3-cp312-none-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.8 kB ? eta -:--:--
#    ---------------------------------------- 138.8/138.8 kB ? eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ---------------------------------------- 53.0/53.0 kB ? eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB ? eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, PyYAML, packaging, orjson, mypy-extensions, multidict, jsonpointer, greenlet, frozenlist, attrs, yarl, typing-inspect, SQLAlchemy, marshmallow, jsonpatch, aiosignal, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.30 aiohttp-3.9.5 aiosignal-1.3.1 attrs-23.2.0 dataclasses-json-0.6.6 frozenlist-1.4.1 greenlet-3.0.3 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.0 langchain-core-0.2.0 langchain-text-splitters-0.2.0 langsmith-0.1.59 marshmallow-3.21.2 multidict-6.0.5 mypy-extensions-1.0.0 orjson-3.10.3 packaging-23.2 tenacity-8.3.0 typing-inspect-0.9.0 yarl-1.9.4
# Collecting langchain_openai
#   Downloading langchain_openai-0.1.7-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_openai) (0.2.0)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_openai) (1.30.1)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.7.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (0.1.59)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (8.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.11.0)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain_openai)
#   Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 675.2 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain_openai) (3.7)
# Requirement already satisfied: certifi in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain_openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain_openai) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain_openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain_openai) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.2.1)
# Requirement already satisfied: colorama in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.24.0->langchain_openai) (0.4.6)
# Downloading langchain_openai-0.1.7-py3-none-any.whl (34 kB)
# Downloading tiktoken-0.7.0-cp312-cp312-win_amd64.whl (799 kB)
#    ---------------------------------------- 0.0/799.3 kB ? eta -:--:--
#    ---------------------- ---------------- 460.8/799.3 kB 14.5 MB/s eta 0:00:01
#    --------------------------------------- 799.3/799.3 kB 16.8 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.5 kB ? eta -:--:--
#    ---------------------------------------- 268.5/268.5 kB ? eta 0:00:00
# Installing collected packages: regex, tiktoken, langchain_openai
# Successfully installed langchain_openai-0.1.7 regex-2024.5.15 tiktoken-0.7.0
# Collecting langchain_community
#   Downloading langchain_community-0.2.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (0.6.6)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (0.1.59)
# Requirement already satisfied: numpy<2,>=1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Downloading langchain_community-0.2.0-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.1 MB 2.8 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.1 MB 4.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 5.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.1 MB 6.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.1 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.9 MB/s eta 0:00:00
# Installing collected packages: langchain_community
# Successfully installed langchain_community-0.2.0
# Requirement already satisfied: pymongo in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (4.7.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: python-dotenv in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: azure-core in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (1.30.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-core) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-core) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-core) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (2024.2.2)
# Requirement already satisfied: azure-cosmos in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (4.7.0)
# Requirement already satisfied: azure-core>=1.25.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-cosmos) (1.30.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-cosmos) (4.11.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-core>=1.25.1->azure-cosmos) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from azure-core>=1.25.1->azure-cosmos) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atheerth\onedrive\documents\github\azuredataretrievalaugmentedgenerationsamples\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (2024.2.2)

# %%
from langchain_community.cache import AzureCosmosDBSemanticCache
from langchain.globals import set_llm_cache
import urllib 

AzureCosmosDBSemanticCache
from langchain_community.vectorstores.azure_cosmos_db import (
    CosmosDBSimilarityType,
    CosmosDBVectorSearchType,
)

from langchain.chains import ConversationalRetrievalChain, LLMChain
from langchain.prompts import PromptTemplate

from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from langchain.globals import set_llm_cache

import pymongo
from dotenv import load_dotenv

# %%
from dotenv import dotenv_values

# specify the name of the .env file name 
env_name = "example.env" # following example.env template change to your own .env file name
config = dotenv_values(env_name)

COSMOS_MONGO_USER = config['cosmos_db_mongo_user']
COSMOS_MONGO_PWD = config['cosmos_db_mongo_pwd']
COSMOS_MONGO_SERVER = config['cosmos_db_mongo_server']
DIMENSIONS = int(config['openai_embeddings_dimensions'])

# %%
INDEX_NAME = "VectorSearchIndex"
NAMESPACE = "ExampleDB.CachingCollection"

CONNECTION_STRING = ("mongodb+srv://"+COSMOS_MONGO_USER+":"+COSMOS_MONGO_PWD+"@"+COSMOS_MONGO_SERVER+"?tls=true&authMechanism=SCRAM-SHA-256&retrywrites=false&maxIdleTimeMS=120000")

DB_NAME, COLLECTION_NAME = NAMESPACE.split(".")
mongo_client = pymongo.MongoClient(CONNECTION_STRING)
# Out:
# C:\Users\atheerth\AppData\Local\Temp\ipykernel_28888\2621025392.py:7: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   mongo_client = pymongo.MongoClient(CONNECTION_STRING)

# %%
def init_llm_chain():

    # Clear old cache if it exists
    mongo_client[DB_NAME][COLLECTION_NAME].drop_indexes()
    mongo_client[DB_NAME].drop_collection(COLLECTION_NAME)

    # Define a template for the LLM prompt
    prompt_template = """
    You are an upbeat AI assistant who is excited to help answer questions. 

    Question: {question}
    If you don't know the answer, just say that you don't know, don't try to make up an answer.
    """
    chatbot_prompt = PromptTemplate(
        template = prompt_template, input_variables = ["question", "context"])

    # Requires model version 0301 or more recent
    # Point to completions model deployed in Azure OpenAI
    llm = AzureChatOpenAI(
        deployment_name=config['openai_completions_deployment'],
        model_name=config['openai_completions_model'],
        api_key=config['openai_api_key'],
        azure_endpoint=config['openai_api_endpoint'],
        api_version=config['openai_api_version'],
        cache=True,
        n=1)

    # Point to embeddings model deployed in Azure OpenAI
    embeddings = AzureOpenAIEmbeddings(
        azure_deployment=config['openai_embeddings_deployment'],
        model=config['openai_embeddings_model'],
        api_key=config['openai_api_key'],
        azure_endpoint=config['openai_api_endpoint'],
        dimensions=DIMENSIONS)

    # Setup simple LLM chain
    llm_chain = LLMChain(llm = llm, prompt=chatbot_prompt)

    # Setup semantic cache for LLM
    num_lists = 1
    similarity_algorithm = CosmosDBSimilarityType.COS
    kind = CosmosDBVectorSearchType.VECTOR_IVF

    score_threshold = 0.9

    sem_cache = AzureCosmosDBSemanticCache(
            cosmosdb_connection_string=CONNECTION_STRING,
            cosmosdb_client=None,
            embedding=embeddings,
            database_name=DB_NAME,
            collection_name=COLLECTION_NAME,
            num_lists=num_lists,
            similarity=similarity_algorithm,
            kind=kind,
            dimensions=DIMENSIONS,
            score_threshold=score_threshold)

    set_llm_cache(sem_cache)

    return llm_chain

# %%
# Initialize llm chain
llm_chain = init_llm_chain()

# %%
# %%time
# The first time, the quesiton/response is not yet cachced in Cosmos DB, so retrieval should be slower
llm_chain.invoke("Tell me something interesting about beer making")

# %%
# %%time
# This quesiton/response is not yet cachced in Cosmos DB, so retrieval should be slower
llm_chain("Tell me a joke about tomatoes and food.")

# %%
# %%time
# The second time, the quesiton/response is cached in Cosmos DB, so retrieval should be faster
llm_chain("Tell me something interesting about beer making")

# %%
# %%time
# This question is semantically similar to the previous one within the score_threshold amount, so retrieval should be faster
llm_chain("How do I make beer?")
